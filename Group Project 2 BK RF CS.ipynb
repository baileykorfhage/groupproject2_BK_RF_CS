# %%
import random

def mainlottonumbers():
    mainnumbers=[]
    count=0
    while count < 5:
        mainnumbers.append(random.randint(1,70))
        count=count+1
    return mainnumbers

powerballnumber=random.randint(1,27)
tries=2
while True:
    player=input("\nEnter '$2' to play or enter 'stop' to stop playing: ")
    if player=='$2':
        num1=int(input('\nEnter your first number (1-69): '))
        num2=int(input('Enter your second number (1-69): '))
        num3=int(input('Enter your third number (1-69): '))
        num4=int(input('Enter your fourth number (1-69): '))
        num5=int(input('Enter your fifth number (1-69): '))
        powerball=int(input('Enter your powerball number (1-26): '))

        yourchoice=[]
        yourchoice.append(num1)
        yourchoice.append(num2)
        yourchoice.append(num3)
        yourchoice.append(num4)
        yourchoice.append(num5)

        if num1 in mainlottonumbers():
            if num2 in mainlottonumbers():
                if num3 in mainlottonumbers():
                    if num4 in mainlottonumbers():
                        if num5 in mainlottonumbers():
                            if powerballnumber==powerball:
                                print('You won the lottery!')
        else:
            print ('\nYou are not the winner!')
            
    
        print('\nHere were the winning numbers: ', mainlottonumbers())
        print('Here was the winning powerball number: ', powerballnumber)
        print('Here is your numbers: ', yourchoice)
        print('Here is your powerball number', powerball)
        print('You have spent $'+str(tries))
    else:
        break
    tries=tries+2
# Out:
# Enter '$2' to play or enter 'stop' to stop playing: $2
#
# Enter your first number (1-69): 56
# Enter your second number (1-69): 56
# Enter your third number (1-69): 56
# Enter your fourth number (1-69): 56
# Enter your fifth number (1-69): 6
# Enter your powerball number (1-26): 5
#
# You are not the winner!
#
# Here were the winning numbers:  [10, 68, 52, 6, 56]
# Here was the winning powerball number:  12
# Here is your numbers:  [56, 56, 56, 56, 6]
# Here is your powerball number 5
# You have spent $2
#
# Enter '$2' to play or enter 'stop' to stop playing: $2
#
# Enter your first number (1-69): 56
# Enter your second number (1-69): 56
# Enter your third number (1-69): 56
# Enter your fourth number (1-69): 56
# Enter your fifth number (1-69): 56
# Enter your powerball number (1-26): 3
#
# Here were the winning numbers:  [3, 15, 2, 59, 38]
# Here was the winning powerball number:  12
# Here is your numbers:  [56, 56, 56, 56, 56]
# Here is your powerball number 3
# ...
